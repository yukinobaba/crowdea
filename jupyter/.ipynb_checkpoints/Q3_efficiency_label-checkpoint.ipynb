# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from pathlib import Path
import pandas as pd
import numpy as np
import collections
import scipy.stats

import warnings
warnings.filterwarnings('ignore')

# %%
data_cats = ['idea', 'design']
data_keys = {'idea': ['bike', 'cheat', 'meeting', 'night', 'visitor'], 
             'design': ['ai_character', 'olympic']}
data_keys_arr = data_keys['idea'] + data_keys['design']
d_arr = [2, 3]
num_evaluators_arr = [20, 50, 100]
methods = ['crowdea_%d' % d for d in d_arr]
methods += ['blade_chest_inner_nonneg_%d_x' % d for d in d_arr] + ['blade_chest_inner_nonneg_%d_y' % d for d in d_arr]
methods += ['bpr_nonneg_%d' % d for d in d_arr]
methods += ['crowdbt', 'bt']

# %%
ndcg5_dfs = []
ndcg10_dfs = []
for num_evaluators in num_evaluators_arr:
    for trial in range(10):
        # implemented in code/best_ndcg.py
        ndcg5_df = pd.read_csv('../ndcg/ndcg5_data_e%d_%d.csv' % (num_evaluators, trial), index_col=0)
        ndcg10_df = pd.read_csv('../ndcg/ndcg10_data_e%d_%d.csv' % (num_evaluators, trial), index_col=0)
        ndcg5_df['num_evaluators'] = num_evaluators
        ndcg5_df['trial'] = trial
        ndcg10_df['num_evaluators'] = num_evaluators
        ndcg10_df['trial'] = trial
        ndcg5_dfs.append(ndcg5_df)
        ndcg10_dfs.append(ndcg10_df)
        
ndcg5_df = pd.concat(ndcg5_dfs)
ndcg10_df = pd.concat(ndcg10_dfs)

score_dfs = {}
score_dfs['ndcg5'] = ndcg5_df
score_dfs['ndcg10'] = ndcg10_df

# %%
# select best parameters of BT and CrowdBT for each (measure, data_key)
best_params = collections.defaultdict(dict)

for measure in score_dfs.keys():
    score_df = score_dfs[measure]
    for method in methods:        
        if 'crowdea' in method:
            continue
        avg_df = score_df.loc[score_df.method == method].groupby(['data_key', 'method', 'num_evaluators', 'trial', 'param']).mean()
        for data_key in data_keys_arr:
            for num_evaluators in num_evaluators_arr:
                if data_key == 'olympic' and num_evaluators == 100:
                    continue
                for trial in range(10):
                    tmp_df = avg_df.loc[(data_key, method, num_evaluators, trial)]
                    tmp_df = tmp_df.sample(tmp_df.shape[0]) # for tie-breaking
                    best_params[measure][(method, data_key, num_evaluators, trial)] = tmp_df.sort_values(measure, ascending=False).index[0]

# %%
best_params['ndcg5']
# Out:
# {('blade_chest_inner_nonneg_2_x', 'bike', 20, 0): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 1): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 2): 0.1,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 3): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 4): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 5): 0.1,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 6): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 7): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 8): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 20, 9): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 0): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 1): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 2): 0.1,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 3): 0.001,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 4): 0.1,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 5): 0.01,
#  ('blade_chest_inner_nonneg_2_x', 'bike', 50, 6): 0.001,
# ...

# %%
ndcg5_data = []
ndcg10_data = []

ndcg5_df = score_dfs['ndcg5']
ndcg10_df = score_dfs['ndcg10']

for data_key in data_keys_arr:
    for method in methods:
        for num_evaluators in num_evaluators_arr:
            if data_key == 'olympic' and num_evaluators == 100:
                    continue
                    
            for trial in range(10):
                if 'crowdea' in method:
                    ndcg5 = ndcg5_df.loc[(ndcg5_df.data_key == data_key) & 
                                         (ndcg5_df.num_evaluators == num_evaluators) & 
                                         (ndcg5_df.method == method) & 
                                         (ndcg5_df.trial == trial), 'ndcg5'].values.mean()
                    ndcg10 = ndcg10_df.loc[(ndcg10_df.data_key == data_key) & 
                                         (ndcg10_df.num_evaluators == num_evaluators) & 
                                         (ndcg10_df.method == method) & 
                                         (ndcg10_df.trial == trial), 'ndcg10'].values.mean()
                else:
                    param_ndcg5 = best_params['ndcg5'][(method, data_key, num_evaluators, trial)]
                    param_ndcg10 = best_params['ndcg10'][(method, data_key, num_evaluators, trial)]
                    
                    ndcg5 = ndcg5_df.loc[(ndcg5_df.data_key == data_key) & 
                                         (ndcg5_df.num_evaluators == num_evaluators) & 
                                         (ndcg5_df.method == method) & 
                                         (ndcg5_df.trial == trial) & 
                                         (ndcg5_df.param == param_ndcg5), 'ndcg5'].values.mean()
                    ndcg10 = ndcg10_df.loc[(ndcg10_df.data_key == data_key) & 
                                         (ndcg10_df.num_evaluators == num_evaluators) & 
                                         (ndcg10_df.method == method) & 
                                         (ndcg10_df.trial == trial) & 
                                         (ndcg10_df.param == param_ndcg10), 'ndcg10'].values.mean()
                    
                ndcg5_data.append({'data_key': data_key, 'ndcg5': ndcg5, 'method': method, 
                                       'num_evaluators': num_evaluators, 'trial': trial})
                ndcg10_data.append({'data_key': data_key, 'ndcg10': ndcg10, 'method': method, 
                                       'num_evaluators': num_evaluators, 'trial': trial})
                
score_dfs['ndcg5'] = pd.DataFrame(ndcg5_data)
score_dfs['ndcg10'] = pd.DataFrame(ndcg10_data)

# %%
score_dfs['ndcg5'].method.unique()
# Out:
# array(['crowdea_2', 'crowdea_3', 'blade_chest_inner_nonneg_2_x',
#        'blade_chest_inner_nonneg_3_x', 'blade_chest_inner_nonneg_2_y',
#        'blade_chest_inner_nonneg_3_y', 'bpr_nonneg_2', 'bpr_nonneg_3',
#        'crowdbt', 'bt'], dtype=object)

# %%
avg_dfs = {}
for measure in score_dfs.keys():
    avg_dfs[measure] = score_dfs[measure].groupby(['data_key', 'method', 'num_evaluators']).mean()

# %%
avg_dfs['ndcg5'].loc['bike']
# Out:
#                                                 ndcg5  trial
# method                       num_evaluators
# blade_chest_inner_nonneg_2_x 20              0.779967    4.5
#                              50              0.781750    4.5
#                              100             0.762443    4.5
# blade_chest_inner_nonneg_2_y 20              0.755785    4.5
#                              50              0.767227    4.5
#                              100             0.744043    4.5
# blade_chest_inner_nonneg_3_x 20              0.821883    4.5
#                              50              0.811872    4.5
#                              100             0.815240    4.5
# blade_chest_inner_nonneg_3_y 20              0.805780    4.5
#                              50              0.791333    4.5
#                              100             0.793344    4.5
# bpr_nonneg_2                 20              0.752177    4.5
#                              50              0.806300    4.5
# ...

# %%
result_dfs = {}

for measure in score_dfs.keys():
    tmp_methods = ['crowdea_%d' % d for d in d_arr]
    tmp_methods += ['blade_chest_inner_nonneg_%d' % d for d in d_arr] + ['blade_chest_inner_nonneg_%d' % d for d in d_arr]
    tmp_methods += ['bpr_nonneg_%d' % d for d in d_arr]
    tmp_methods += ['crowdbt', 'bt']        
        
    for method in tmp_methods:    
        result_df = pd.DataFrame(index=data_keys_arr, 
                                 columns=['#evaluators=%d' % n for n in num_evaluators_arr])
        
        for data_key in data_keys_arr:
            for num_evaluators in num_evaluators_arr:
                if data_key == 'olympic' and num_evaluators == 100:
                    v = np.nan
                else:
                    if 'blade_chest_inner' in method:
                        v_x = avg_dfs[measure].loc[(data_key, method+'_x', num_evaluators), measure]
                        v_y = avg_dfs[measure].loc[(data_key, method+'_y', num_evaluators), measure]
                        v = np.max([v_x, v_y])
                    else:
                        v = avg_dfs[measure].loc[(data_key, method, num_evaluators), measure]
                    
                result_df.loc[data_key, '#evaluators=%d' % num_evaluators] = v
        result_dfs[(measure, method)] = result_df

# %%
result_dfs.keys()
# Out:
# dict_keys([('ndcg5', 'crowdea_2'), ('ndcg5', 'crowdea_3'), ('ndcg5', 'blade_chest_inner_nonneg_2'), ('ndcg5', 'blade_chest_inner_nonneg_3'), ('ndcg5', 'bpr_nonneg_2'), ('ndcg5', 'bpr_nonneg_3'), ('ndcg5', 'crowdbt'), ('ndcg5', 'bt'), ('ndcg10', 'crowdea_2'), ('ndcg10', 'crowdea_3'), ('ndcg10', 'blade_chest_inner_nonneg_2'), ('ndcg10', 'blade_chest_inner_nonneg_3'), ('ndcg10', 'bpr_nonneg_2'), ('ndcg10', 'bpr_nonneg_3'), ('ndcg10', 'crowdbt'), ('ndcg10', 'bt')])

# %% [markdown]
# ---

# %% [markdown]
# # Avg. of nDCG@5 among viewpoints and 10 trials

# %%
print('CrowDEA (d=2)')
result_dfs[('ndcg5', 'crowdea_2')]
# Out:
# CrowDEA (d=2)
#              #evaluators=20 #evaluators=50 #evaluators=100
# bike               0.828822       0.841553        0.831244
# cheat              0.851902       0.854621        0.866077
# meeting             0.85991        0.86973        0.875985
# night              0.887356       0.899008         0.90392
# visitor            0.914192       0.931279        0.935281
# ai_character       0.919979        0.92218        0.934677
# olympic            0.942828        0.94009             NaN

# %%
print('CrowDEA (d=3)')
result_dfs[('ndcg5', 'crowdea_3')]
# Out:
# CrowDEA (d=3)
#              #evaluators=20 #evaluators=50 #evaluators=100
# bike               0.776501       0.805355        0.811113
# cheat              0.811897       0.826495        0.849947
# festival           0.873241       0.880217        0.882815
# meeting            0.818275       0.833829        0.848856
# name               0.869535       0.886046        0.882675
# night              0.847744       0.855332        0.842371
# trash              0.768148       0.764737        0.792339
# visitor            0.894566       0.905795        0.909638
# ai_character       0.889168       0.898972        0.913066
# olympic            0.925316       0.925969             NaN

# %% [markdown]
# ---

# %% [markdown]
# # Avg. of nDCG@10 among viewpoints and 10 trials

# %%
print('CrowDEA (d=2)')
result_dfs[('ndcg10', 'crowdea_2')]
# Out:
# CrowDEA (d=2)
#              #evaluators=20 #evaluators=50 #evaluators=100
# bike               0.801008       0.812019        0.810935
# cheat              0.815456       0.823822        0.834935
# festival            0.89388       0.899105        0.901573
# meeting            0.826191       0.838476        0.847937
# name               0.887698       0.898723        0.900011
# night              0.815917       0.836116        0.839809
# trash              0.765342       0.768089        0.787447
# visitor            0.889596       0.916447        0.919566
# ai_character         0.9004       0.903069        0.914871
# olympic            0.921627       0.925481             NaN

# %%
print('CrowDEA (d=3)')
result_dfs[('ndcg10', 'crowdea_3')]
# Out:
# CrowDEA (d=3)
#              #evaluators=20 #evaluators=50 #evaluators=100
# bike                0.79977       0.828444        0.834045
# cheat               0.82609       0.844407        0.864788
# festival           0.892709       0.898044        0.902542
# meeting            0.833837       0.851367        0.864541
# name               0.886102       0.898343        0.896578
# night              0.860187       0.868476        0.858807
# trash              0.792549       0.795896        0.815037
# visitor            0.903992       0.917583        0.922137
# ai_character       0.900025       0.908715          0.9232
# olympic            0.933981        0.93327             NaN

# %% [markdown]
# ---

# %%
data_key_tex = {}
for data_key in data_keys_arr:
    data_key_tex[data_key] = data_key.capitalize()
    if data_key == 'ai_character':
        data_key_tex[data_key] = 'Character'
        
color_dict = {
    'bt': '#e4ad44', 
    'crowdbt': '#f95039',
    'crowdea': '#1790d2',
    'bpr': '#80187a',
    'blade-chest': '#d81B60',
    }

marker_dict = {
    'bt': 'x',
    'crowdbt': '.', 
    'crowdea': 'o',
    'bpr': 's',
    'blade-chest': 'p'
}

label_dict = {
    'bt': 'BT',
    'crowdbt': 'CrowdBT',
    'crowdea': 'CrowDEA',
    'bpr': 'BPR', 
    'blade-chest': 'Blade-chest'
}

methods = ['crowdea_%d' % d for d in d_arr]
methods += ['blade_chest_inner_nonneg_%d' % d for d in d_arr] + ['blade_chest_inner_nonneg_%d' % d for d in d_arr]
methods += ['bpr_nonneg_%d' % d for d in d_arr]
methods += ['crowdbt', 'bt'] 
    
for method in methods:
    if 'crowdea' in method:
        color_dict[method] = color_dict['crowdea']
        marker_dict[method] = marker_dict['crowdea']
        label_dict[method] = label_dict['crowdea']
    elif 'blade_chest' in method:
        color_dict[method] = color_dict['blade-chest']
        marker_dict[method] = marker_dict['blade-chest']
        label_dict[method] = label_dict['blade-chest']
    elif 'bpr' in method:
        color_dict[method] = color_dict['bpr']
        marker_dict[method] = marker_dict['bpr']
        label_dict[method] = label_dict['bpr']
        
methods_d = {}
methods_d[2] = ['bt', 'crowdbt', 'blade_chest_inner_nonneg_2', 'bpr_nonneg_2', 'crowdea_2']
methods_d[3] = ['bt', 'crowdbt', 'blade_chest_inner_nonneg_3', 'bpr_nonneg_3', 'crowdea_3']

# %%
measure = 'ndcg5'
d = 2

plt.figure(figsize=(16, 7))
plt.style.use('seaborn-ticks')
plt.rcParams["font.size"] = 16

x = num_evaluators_arr

for i, data_key in enumerate(data_keys_arr):
    plt.subplot(2, 4, i+1)
    
    for method in methods_d[d]:
        y = [result_dfs[(measure, method)].loc[data_key, '#evaluators=%d' % num_evaluators] for num_evaluators in num_evaluators_arr]
        label = label_dict[method]
        plt.plot(x, y, '%s-' % marker_dict[method], color=color_dict[method], label=label, lw=3, ms=8, mew=1.5, mec=color_dict[method])

    plt.title(data_key_tex[data_key])    
    plt.ylim(0.7, 1.0)
    plt.xlabel('Num. of evaluators', labelpad=2)
    plt.ylabel('nDCG@10', labelpad=2)
    if data_key == 'olympic':
        plt.xticks([20, 50, 100]) 
    else:
        plt.xticks([20, 50, 100]) 
    
anchor_y = -0.7
#plt.legend(loc="lower center", bbox_to_anchor=(-0.8, anchor_y), ncol=4)
plt.tight_layout(pad=0., w_pad=0.5, h_pad=0.5)
plt.savefig('fig_efficiency_evaluator_d%d_%s.pdf' % (d, measure), bbox_inches="tight", pad_inches=0.)
